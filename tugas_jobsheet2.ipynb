# %% [markdown]
# <a href="https://colab.research.google.com/github/nazwa48/PEMB-MESIN/blob/main/tugas_jobsheet2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TUGAS KELOMPOK

# %% [markdown]
# Deskripsi Tugas
# Pada tugas pratikum ini Anda akan menggunakan data "Wisconsin Breast Cancer". Data tersebut terdiri dari 569 data yang digunakan untuk mendiagnonis jenis kanker Malignant (M) dan Benign (B). Tugas Anda adalah,
#
# Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.
#
# Lakukan proses encoding pada kolom "diagnosis".
#
# Lakukan proses standarisasi pada semua kolom yang memiliki nilai numerik.
#
# Lakukan proses stratified split data untuk membuat data latih dan data uji dengan rasio 80:20.

# %% [markdown]
# # JAWAB
# 1. Upload data wbc, lalu Import library yang dibutuhkan kemudian, load data kedalam DataFrame Pandas.

# %%
from google.colab import files
uploaded = files.upload() # upload dataset
# Out:
#      <input type="file" id="files-3d1d11f2-5841-4773-a43e-c98bdd60013d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d1d11f2-5841-4773-a43e-c98bdd60013d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

df = pd.read_csv('wbc.csv') # load dataset

# %% [markdown]
# ## Soal 1
# Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.

# %%
# Disini saya membuang kolom 'id' dan 'Unnamed: 32'
df = df.drop(columns=['id', 'Unnamed: 32'], errors='ignore')

# %% [markdown]
# Tampilan hasil dari data diatas

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# # Soal 2
# Lakukan proses encoding pada kolom "diagnosis".

# %%
# 2. Lakukan proses encoding pada kolom "diagnosis".
le = LabelEncoder()
df['diagnosis'] = le.fit_transform(df['diagnosis'])

# %% [markdown]
# Tampilan hasil dari data diatas

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# # Soal 3
# Lakukan proses standarisasi pada semua kolom yang memiliki nilai numerik.

# %%
# Lakukan proses standarisasi pada semua kolom yang memiliki nilai numerik.
scaler = StandardScaler()
numerical_columns = df.columns.drop('diagnosis') # kecuali kolom diagnosis
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# %% [markdown]
# Tampilan hasil dari data diatas

# %%
df.head(50)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           1     1.097064     -2.073335        1.269934   0.984375
# 1           1     1.829821     -0.353632        1.685955   1.908708
# 2           1     1.579888      0.456187        1.566503   1.558884
# 3           1    -0.768909      0.253732       -0.592687  -0.764464
# 4           1     1.750297     -1.151816        1.776573   1.826229
# 5           1    -0.476375     -0.835335       -0.387148  -0.505650
# 6           1     1.170908      0.160649        1.138125   1.095295
# 7           1    -0.118517      0.358450       -0.072867  -0.218965
# 8           1    -0.320167      0.588830       -0.184080  -0.384207
# 9           1    -0.473535      1.105439       -0.329482  -0.509063
# 10          1     0.537556      0.919273        0.442011   0.406453
# 11          1     0.469393     -0.325708        0.479082   0.358672
# 12          1     1.432201      1.282296        1.665360   1.331355
# ...

# %% [markdown]
# # Soal 4
#  Lakukan proses stratified split data untuk membuat data latih dan data uji dengan rasio
# 80:20.

# %%
#  Lakukan proses stratified split data untuk membuat data latih dan data uji dengan rasio 80:20.
X = df.drop(columns=['diagnosis'])
y = df['diagnosis']

# %% [markdown]
# ## Melihat Data setelah code diatas dieksekusi
# 1. Melihat Lima Baris Pertama dari Data Latih

# %%
# Melihat Lima Baris Pertama dari Data Latih
print("Data Latih (X_train): ")
print(X.head())
# Out:
# Data Latih (X_train):
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
# ...
